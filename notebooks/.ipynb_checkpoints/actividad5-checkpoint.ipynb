# %%
import sys
sys.path.append("../")
from src.ejercicio5 import calcular_costo
peso = float(input("ingrese el peso del paquete en kilogramos: "))
zona=input("ingrese la zona donde sera enviado, local,regional o nacional: ")
resultado = calcular_costo(peso,zona)
print(f"costo de envio: {resultado}")
# Out:
# ingrese el peso del paquete en kilogramos:  4
# ingrese la zona donde sera enviado, local,regional o nacional:  regional
# costo de envio: 2500
