# %%
import sys
sys.path.append("../")
from src.ejercicio8 import cifrar_cesar 
mensaje = input("ingrese el mensaje a cifrar: ")
desplazamiento = int(input("ingrese el desplazamiento: "))

cifrado = cifrar_cesar(mensaje,desplazamiento)
descifrado = cifrar_cesar(cifrado,-desplazamiento)

print("mensaje cifrado: ",cifrado)
print("mensaje descifrado: ",descifrado)
# Out:
# ingrese el mensaje a cifrar:  boffe te amo
# ingrese el desplazamiento:  4
# mensaje cifrado:  fsjji xi eqs
# mensaje descifrado:  boffe te amo
