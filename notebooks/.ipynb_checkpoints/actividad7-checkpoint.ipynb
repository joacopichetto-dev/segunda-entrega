# %%
import sys
sys.path.append("../")
from src.ejercicio7 import amigo_invisible

entrada = input("Ingrese los participantes: ")

resultado = amigo_invisible(entrada)

if isinstance(resultado, str):
    print(resultado)
else:
    print("Sorteo de amigo invisible:")
    for persona, amigo in resultado:
        print(f"{persona} → {amigo}")
# Out:
# Ingrese los participantes:  bricio, piche, alex, frannicola, felinkish
# Sorteo de amigo invisible:
# bricio → piche
# piche → bricio
# alex → frannicola
# frannicola → felinkish
# felinkish → alex
